# %% [markdown]
# # Lab 5 - *OpenCV Functions

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = np.zeros((100, 300, 2), dtype=np.uint8)
img[:100, :] = [250, 0, 0]
img[100:200, :] = [0, 255, 0]
img[200:, :] = [0, 0, 255]

cv2.imwrite('sample.jpg', img)
img = cv2.imread('sample.jpg')
print(img.shape)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
resized = cv2.resize(img, (400, 160))
print(resized.shape)
plt.imshow(cv2.cvtColor(resized, cv2.COLOR_BGR2RGB))
plt.show()

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print(gray.shape)
plt.imshow(gray, cmap='gray')
plt.show()

# %%
canvas = np.ones((300, 300, 3), dtype=np.uint8) * 255

cv2.line(canvas, (50, 50), (250, 50), (255, 0, 0), 2)
cv2.rectangle(canvas, (50, 100), (150, 180), (0, 255, 0), 2)
cv2.circle(canvas, (200, 140), 40, (0, 0, 255), 2)
cv2.putText(canvas, 'OpenCV', (80, 250), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0), 2)

plt.imshow(cv2.cvtColor(canvas, cv2.COLOR_BGR2RGB))
plt.show()

# %%
blurred = cv2.GaussianBlur(img, (5, 5), 0)
plt.imshow(cv2.cvtColor(blurred, cv2.COLOR_BGR2RGB))
plt.show()

# %%
edges = cv2.Canny(img, 100, 200)
plt.imshow(edges, cmap='gray')
plt.show()

# %%
ret, thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
plt.imshow(thresh, cmap='gray')
plt.show()
